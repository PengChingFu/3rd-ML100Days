# %% [markdown]
# 作業1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

# %%
x_lin = np.linspace(0, 100, 101)

# %%
y = (x_lin + np.random.randn(101) * 5) * w + b

# %%
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.576

# %%
def mean_square_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse
MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 240.748

# %% [markdown]
# 作業2 Crimes in Boston

# %% [markdown]
# 1.你選的這組資料為何重要
# 對公眾治安很有貢獻
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 由Analyze Boston而來、透過發生罪行的種類、日期、時間、地點進行蒐集資料
# 3.蒐集而來的資料型態為何
# 結構化的表格
# 4.這組資料想解決的問題如何評估
# 在什麼地點/時間/最容易發生什麼罪行，以利於在該處/時間點提前做防範，減少犯罪率，透過回歸進行預測

# %% [markdown]
# 作業3：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# %% [markdown]
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績:單位時間成本所得到的獲利
# 假設：透過載客時間所能得到的營收扣除成本，預估出哪個地段可獲得的業績最大效益
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 資料：載客時間/地點/距離/營收/成本
# 如何蒐集：透過導航記載路程及時間
# 3. 蒐集而來的資料型態為何
# 結構化之數值
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 在什麼時間/地點是最容易載到客人，並可獲得最大營利：迴歸 (Mean Squared Error, MSE)
